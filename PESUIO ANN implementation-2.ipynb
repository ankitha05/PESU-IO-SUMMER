# %%
import numpy as np  
import matplotlib.pyplot as plt

np.random.seed(42)

cat_images = np.random.randn(700, 2) + np.array([0, -3])  
mouse_images = np.random.randn(700, 2) + np.array([3, 3])  
dog_images = np.random.randn(700, 2) + np.array([-3, 3])

feature_set = np.vstack([cat_images, mouse_images, dog_images])

labels = np.array([0]*700 + [1]*700 + [2]*700)

one_hot_labels = np.zeros((2100, 3))

for i in range(2100):  
    one_hot_labels[i, labels[i]] = 1

plt.figure(figsize=(10,7))  
plt.scatter(feature_set[:,0], feature_set[:,1], c=labels, cmap='plasma', s=100, alpha=0.5)  
plt.show()

def sigmoid(x):  
    return 1/(1+np.exp(-x))

def sigmoid_der(x):  
    return sigmoid(x) *(1-sigmoid (x))

def softmax(A):  
    expA = np.exp(A)
    return expA / expA.sum(axis=1, keepdims=True)

instances = feature_set.shape[0]  
attributes = feature_set.shape[1]  
hidden_nodes = 4  
output_labels = 3

wh = np.random.rand(attributes,hidden_nodes)  
bh = np.random.randn(hidden_nodes)

wo = np.random.rand(hidden_nodes,output_labels)  
bo = np.random.randn(output_labels)  
lr = 10e-4

error_cost = []

for epoch in range(50000):  
############# feedforward

    # Phase 1
    zh = np.dot(feature_set, wh) + bh
    ah = sigmoid(zh)

    # Phase 2
    zo = np.dot(ah, wo) + bo
    ao = softmax(zo)

########## Back Propagation

########## Phase 1

    dcost_dzo = ao - one_hot_labels
    dzo_dwo = ah

    dcost_wo = np.dot(dzo_dwo.T, dcost_dzo)

    dcost_bo = dcost_dzo

########## Phases 2

    dzo_dah = wo
    dcost_dah = np.dot(dcost_dzo , dzo_dah.T)
    dah_dzh = sigmoid_der(zh)
    dzh_dwh = feature_set
    dcost_wh = np.dot(dzh_dwh.T, dah_dzh * dcost_dah)

    dcost_bh = dcost_dah * dah_dzh

    # Update Weights ================

    wh -= lr * dcost_wh
    bh -= lr * dcost_bh.sum(axis=0)

    wo -= lr * dcost_wo
    bo -= lr * dcost_bo.sum(axis=0)

    if epoch % 200 == 0:
        loss = np.sum(-one_hot_labels * np.log(ao))
        print('Loss function value: ', loss)
        error_cost.append(loss)
# Out:
# Loss function value:  3101.2779592613765
# Loss function value:  20.518567596960878
# Loss function value:  13.41539643356695
# Loss function value:  10.806239114192763
# Loss function value:  9.293853043370643
# Loss function value:  8.222335562342456
# Loss function value:  7.427291388788856
# Loss function value:  6.815957335510982
# Loss function value:  6.328800742777296
# Loss function value:  5.9298003420658185
# Loss function value:  5.595779425599992
# Loss function value:  5.31111880551247
# Loss function value:  5.064894173306703
# Loss function value:  4.849225960985245
# Loss function value:  4.658281872646845
# Loss function value:  4.487648995564464
# Loss function value:  4.333924545010694
# Loss function value:  4.1944409886297365
# Loss function value:  4.067076566158791
# Loss function value:  3.9501216803739423
# Loss function value:  3.84218278881702
# Loss function value:  3.7421120397586796
# Loss function value:  3.6489549384881403
# Loss function value:  3.561910868828659
# Loss function value:  3.4803029282919704
# Loss function value:  3.4035546094566893
# Loss function value:  3.3311715805212345
# Loss function value:  3.262727309744717
# Loss function value:  3.197851619664089
# Loss function value:  3.1362214971966
# Loss function value:  3.0775536571780053
# Loss function value:  3.021598480775323
# Loss function value:  2.968135040773049
# Loss function value:  2.916966992639077
# Loss function value:  2.867919160202206
# Loss function value:  2.820834682371858
# Loss function value:  2.7755726158947436
# Loss function value:  2.732005911018041
# Loss function value:  2.6900196938117693
# Loss function value:  2.6495098020256416
# Loss function value:  2.6103815316268513
# Loss function value:  2.5725485592554147
# Loss function value:  2.5359320122452735
# Loss function value:  2.5004596629711355
# Loss function value:  2.4660652283773077
# Loss function value:  2.432687758846988
# Loss function value:  2.4002711032434076
# Loss function value:  2.368763439130748
# Loss function value:  2.3381168589609125
# Loss function value:  2.308287004473608
# Loss function value:  2.2792327427611134
# Loss function value:  2.2509158784471115
# Loss function value:  2.223300897257764
# Loss function value:  2.196354736955454
# Loss function value:  2.1700465821851997
# Loss function value:  2.144347680270907
# Loss function value:  2.1192311754097544
# Loss function value:  2.094671959061147
# Loss function value:  2.070646534622053
# Loss function value:  2.0471328947325125
# Loss function value:  2.0241104097706986
# Loss function value:  2.001559726281367
# Loss function value:  1.9794626742409087
# Loss function value:  1.9578021821990448
# Loss function value:  1.9365621994564524
# Loss function value:  1.9157276245405268
# Loss function value:  1.8952842393313292
# Loss function value:  1.8752186482682012
# Loss function value:  1.8555182221362754
# Loss function value:  1.8361710459918426
# Loss function value:  1.8171658708387084
# Loss function value:  1.7984920687138743
# Loss function value:  1.780139590881468
# Loss function value:  1.7620989288701807
# Loss function value:  1.7443610781204129
# Loss function value:  1.72691750403553
# Loss function value:  1.709760110255253
# Loss function value:  1.6928812089909366
# Loss function value:  1.676273493280374
# Loss function value:  1.6599300110358572
# Loss function value:  1.6438441407729592
# Loss function value:  1.6280095689189977
# Loss function value:  1.6124202686101967
# Loss function value:  1.5970704798947555
# Loss function value:  1.58195469126611
# Loss function value:  1.5670676224562254
# Loss function value:  1.5524042084234582
# Loss function value:  1.5379595844734935
# Loss function value:  1.5237290724544956
# Loss function value:  1.5097081679703996
# Loss function value:  1.495892528558005
# Loss function value:  1.4822779627752167
# Loss function value:  1.4688604201489173
# Loss function value:  1.4556359819323572
# Loss function value:  1.44260085262278
# Loss function value:  1.4297513521911744
# Loss function value:  1.417083908977066
# Loss function value:  1.404595053202367
# Loss function value:  1.3922814110596309
# Loss function value:  1.3801396993313575
# Loss function value:  1.368166720498472
# Loss function value:  1.356359358297753
# Loss function value:  1.3447145736897874
# Loss function value:  1.3332294012006742
# Loss function value:  1.3219009456028725
# Loss function value:  1.3107263789025208
# Loss function value:  1.29970293760251
# Loss function value:  1.2888279202128639
# Loss function value:  1.27809868498194
# Loss function value:  1.2675126478240526
# Loss function value:  1.2570672804212508
# Loss function value:  1.2467601084789308
# Loss function value:  1.236588710116688
# Loss function value:  1.2265507143779437
# Loss function value:  1.2166437998434538
# Loss function value:  1.2068656933353432
# Loss function value:  1.1972141686999862
# Loss function value:  1.1876870456593942
# Loss function value:  1.1782821887220658
# Loss function value:  1.1689975061453501
# Loss function value:  1.1598309489426908
# Loss function value:  1.15078050992963
# Loss function value:  1.141844222803878
# Loss function value:  1.1330201612550952
# Loss function value:  1.1243064381007533
# Loss function value:  1.115701204445294
# Loss function value:  1.1072026488600564
# Loss function value:  1.0988089965819166
# Loss function value:  1.090518508729156
# Loss function value:  1.0823294815330895
# Loss function value:  1.0742402455846567
# Loss function value:  1.0662491650949004
# Loss function value:  1.0583546371690016
# Loss function value:  1.0505550910931674
# Loss function value:  1.042848987634297
# Loss function value:  1.0352348183518914
# Loss function value:  1.027711104922342
# Loss function value:  1.0202763984752763
# Loss function value:  1.0129292789420203
# Loss function value:  1.0056683544161025
# Loss function value:  0.9984922605257935
# Loss function value:  0.991399659818641
# Loss function value:  0.9843892411581193
# Loss function value:  0.9774597191321497
# Loss function value:  0.9706098334737865
# Loss function value:  0.9638383484937407
# Loss function value:  0.9571440525249801
# Loss function value:  0.9505257573791037
# Loss function value:  0.9439822978146187
# Loss function value:  0.9375125310170062
# Loss function value:  0.931115336090319
# Loss function value:  0.9247896135604682
# Loss function value:  0.918534284889868
# Loss function value:  0.9123482920033997
# Loss function value:  0.9062305968255185
# Loss function value:  0.9001801808283841
# Loss function value:  0.8941960445908126
# Loss function value:  0.8882772073678225
# Loss function value:  0.8824227066707787
# Loss function value:  0.8766315978577182
# Loss function value:  0.870902953733838
# Loss function value:  0.8652358641617683
# Loss function value:  0.8596294356817206
# Loss function value:  0.8540827911409127
# Loss function value:  0.8485950693324527
# Loss function value:  0.8431654246431861
# Loss function value:  0.8377930267103879
# Loss function value:  0.8324770600872672
# Loss function value:  0.8272167239167094
# Loss function value:  0.8220112316133915
# Loss function value:  0.8168598105539127
# Loss function value:  0.811761701774754
# Loss function value:  0.806716159677787
# Loss function value:  0.8017224517433894
# Loss function value:  0.796779858250642
# Loss function value:  0.7918876720046353
# Loss function value:  0.7870451980706652
# Loss function value:  0.7822517535150413
# Loss function value:  0.777506667152446
# Loss function value:  0.7728092792995669
# Loss function value:  0.7681589415349408
# Loss function value:  0.7635550164646712
# Loss function value:  0.758996877494093
# Loss function value:  0.75448390860494
# Loss function value:  0.7500155041381213
# Loss function value:  0.745591068581796
# Loss function value:  0.741210016364638
# Loss function value:  0.7368717716541413
# Loss function value:  0.7325757681598977
# Loss function value:  0.7283214489414865
# Loss function value:  0.7241082662212224
# Loss function value:  0.7199356812012256
# Loss function value:  0.7158031638849545
# Loss function value:  0.7117101929030003
# Loss function value:  0.7076562553429941
# Loss function value:  0.703640846583576
# Loss function value:  0.6996634701322288
# Loss function value:  0.6957236374669777
# Loss function value:  0.6918208678817441
# Loss function value:  0.6879546883353228
# Loss function value:  0.6841246333038518
# Loss function value:  0.6803302446366879
# Loss function value:  0.6765710714156112
# Loss function value:  0.672846669817214
# Loss function value:  0.669156602978458
# Loss function value:  0.6655004408652807
# Loss function value:  0.6618777601441358
# Loss function value:  0.6582881440564659
# Loss function value:  0.6547311822959556
# Loss function value:  0.6512064708885416
# Loss function value:  0.6477136120750692
# Loss function value:  0.6442522141965419
# Loss function value:  0.6408218915819203
# Loss function value:  0.6374222644383694
# Loss function value:  0.6340529587438418
# Loss function value:  0.6307136061421303
# Loss function value:  0.6274038438400553
# Loss function value:  0.6241233145069207
# Loss function value:  0.6208716661761524
# Loss function value:  0.6176485521490067
# Loss function value:  0.6144536309003232
# Loss function value:  0.6112865659862857
# Loss function value:  0.6081470259541549
# Loss function value:  0.605034684253871
# Loss function value:  0.6019492191514684
# Loss function value:  0.5988903136443753
# Loss function value:  0.595857655378454
# Loss function value:  0.592850936566716
# Loss function value:  0.5898698539097011
# Loss function value:  0.5869141085175955
# Loss function value:  0.5839834058338138
# Loss function value:  0.5810774555602454
# Loss function value:  0.5781959715839182
# Loss function value:  0.5753386719052689
# Loss function value:  0.5725052785676734
# Loss function value:  0.56969551758865
# Loss function value:  0.56690911889216
# Loss function value:  0.5641458162424764
# Loss function value:  0.5614053471792348
# Loss function value:  0.5586874529538516
# Loss function value:  0.5559918784671144
# Loss function value:  0.5533183722080706
# Loss function value:  0.5506666861941016
# Loss function value:  0.5480365759121015
# Loss function value:  0.5454278002608759
# Loss function value:  0.5428401214946473
# Loss function value:  0.5402733051675983
# Loss function value:  0.5377271200795308
# Loss function value:  0.5352013382225671
# Loss function value:  0.5326957347288385
